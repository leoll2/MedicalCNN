# %% [markdown]
# # Environment setup

# %%
# Connect to Google Drive

from google.colab import drive
drive.mount('/content/gdrive')

# %%
# Copy the dataset from Google Drive to local

# !cp "/content/gdrive/My Drive/CBIS_DDSM.zip" .
# !unzip -qq CBIS_DDSM.zip
# !rm CBIS_DDSM.zip
cbis_path = 'CBIS_DDSM'

# %%
# Import libraries

# %tensorflow_version 1.x
import os
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, SGD, Adam, Nadam
from tensorflow.keras.utils import plot_model

# %%
def load_training():
    """
    Load the training set
    """
    abnorm_patches = np.load(os.path.join(cbis_path, 'numpy data', 'train_tensor.npy'))[1::2]
    base_patches = np.load(os.path.join(cbis_path, 'numpy data', 'train_tensor.npy'))[0::2]
    labels = np.load(os.path.join(cbis_path, 'numpy data', 'train_labels.npy'))[1::2]
    return abnorm_patches, base_patches, labels


def load_testing():
    """
    Load the test set (abnormalities patches and labels, no baseline)
    """
    abnorm_patches = np.load(os.path.join(cbis_path, 'numpy data', 'public_test_tensor.npy'))[1::2]
    base_patches = np.load(os.path.join(cbis_path, 'numpy data', 'public_test_tensor.npy'))[0::2]
    labels = np.load(os.path.join(cbis_path, 'numpy data', 'public_test_labels.npy'))[1::2]
    return abnorm_patches, base_patches, labels


def remap_label(l):
    """
    Remap the labels to 0->mass 1->calcification
    """
    if l == 1 or l == 2:
        return 0
    elif l == 3 or l == 4:
        return 1
    else:
        print("[WARN] Unrecognized label (%d)" % l)
        return None

# %%
# Load training and test images (abnormalities only, no baseline)
train_abn_images, train_base_images, train_labels= load_training()
test_abn_images, test_base_images, test_labels= load_testing()

# Number of images
n_train_img = train_abn_images.shape[0]
n_test_img = test_abn_images.shape[0]
print("Train size: %d \t Test size: %d" % (n_train_img, n_test_img))

# Compute width and height of images
img_w = train_abn_images.shape[1]
img_h = train_abn_images.shape[2]
print("Image size: %dx%d" % (img_w, img_h))

# Remap labels
train_labels = np.array([remap_label(l) for l in train_labels])
test_labels = np.array([remap_label(l) for l in test_labels])

# Create a new dimension for color in the images arrays
train_abn_images = train_abn_images.reshape((n_train_img, img_w, img_h, 1))
train_base_images = train_base_images.reshape((n_train_img, img_w, img_h, 1))
test_abn_images = test_abn_images.reshape((n_test_img, img_w, img_h, 1))
test_base_images = test_base_images.reshape((n_test_img, img_w, img_h, 1))

# Convert from 16-bit (0-65535) to float (0-1)
train_abn_images = train_abn_images.astype('uint16') / 65535
train_base_images = train_base_images.astype('uint16') / 65535
test_abn_images = test_abn_images.astype('uint16') / 65535
test_base_images = test_base_images.astype('uint16') / 65535

# Shuffle the training set (originally sorted by label)
perm = np.random.permutation(n_train_img)
train_abn_images = train_abn_images[perm]
train_base_images = train_base_images[perm]
train_labels = train_labels[perm]

def double_generator(train_abn_images, train_base_images, train_labels, subset, batch_size=128):

    gen = ImageDataGenerator(
        validation_split=0.2,
        rotation_range=180,
        shear_range=15,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='reflect'
    )

    gen.fit(train_abn_images)

    gen_abn = gen.flow(train_abn_images, train_labels,  batch_size=batch_size, subset=subset, seed=1)
    gen_base = gen.flow(train_base_images, train_labels, batch_size=batch_size, subset=subset, seed=1)

    while True:
        abn_img, abn_label = gen_abn.next()
        base_img, _ = gen_base.next()
        yield [abn_img, base_img], abn_label


train_generator = double_generator(train_abn_images, train_base_images, train_labels, 'training', batch_size=128)
validation_generator = double_generator(train_abn_images, train_base_images, train_labels, 'validation', batch_size=128)
# Out:
# Train size: 2676 	 Test size: 336
# Image size: 150x150

# %%
''' Create a Siamese network '''

def create_siamese():

    # Two input channels
    left_input = layers.Input(shape=(150, 150, 1))
    right_input = layers.Input(shape=(150, 150, 1))

    # CNN core
    cnn = models.Sequential()
    cnn.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 1)))
    cnn.add(layers.MaxPooling2D((2, 2)))
    cnn.add(layers.Conv2D(64, (3, 3), activation='relu'))
    cnn.add(layers.MaxPooling2D((2, 2)))
    cnn.add(layers.Conv2D(128, (3, 3), activation='relu'))
    cnn.add(layers.MaxPooling2D((2, 2)))
    cnn.add(layers.Flatten())

    # Feed both input into the same convolutional base
    left_model = cnn(left_input)
    right_model = cnn(right_input)

    # Compute the difference between the two
    diff = layers.Subtract()([left_model, right_model])

    # FC layer
    fc = layers.Flatten()(diff)
    fc = layers.Dense(96, activation="relu")(fc)
    fc = layers.Dropout(0.5)(fc)
    fc = layers.Dense(1, activation="sigmoid")(fc)

    # Instantiate the model
    siamese = models.Model(inputs=[left_input, right_input], outputs=fc)

    return siamese

# %%
siamese_example = create_siamese()
siamese_example.summary()
plot_model(siamese_example, expand_nested=True)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 150, 150, 1) 0
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 36992)        92672       input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 36992)        0           sequential_3[1][0]
#                                                                  sequential_3[2][0]
# __________________________________________________________________________________________________
# flatten_6 (Flatten)             (None, 36992)        0           subtract_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 96)           3551328     flatten_6[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 96)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            97          dropout_2[0][0]
# ==================================================================================================
# Total params: 3,644,097
# Trainable params: 3,644,097
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Instantiate model
siamese = create_siamese()

# Early stopping (stop training after the validation loss reaches the minimum)
earlystopping = EarlyStopping(monitor='val_loss', mode='min', patience=80, verbose=1)

# Callback for checkpointing
checkpoint = ModelCheckpoint('siamese_best.h5', 
        monitor='val_loss', mode='min', verbose=1, 
        save_best_only=True, save_freq='epoch'
)

# Compile the model
siamese.compile(optimizer=RMSprop(learning_rate=0.001, decay=1e-3), loss='binary_crossentropy', metrics=['accuracy'])

# Train
history_siamese = siamese.fit_generator(
        train_generator,
        steps_per_epoch=int(0.8*n_train_img) // 128,
        epochs=500,
        validation_data=validation_generator,
        validation_steps = int(0.2*n_train_img) // 128,
        callbacks=[checkpoint, earlystopping],
        shuffle=True,
        verbose=1,
        initial_epoch=0
)

# Save
models.save_model(siamese, 'siamese_end.h5')
# !cp model* "/content/gdrive/My Drive/models/"
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.7335 - acc: 0.5807Epoch 1/500
#  4/16 [======>.......................] - ETA: 11s - loss: 0.6679 - acc: 0.6016
# Epoch 00001: val_loss improved from inf to 0.66794, saving model to siamese_best.h5
# 16/16 [==============================] - 16s 1s/step - loss: 0.7286 - acc: 0.5830 - val_loss: 0.6679 - val_acc: 0.6016
# Epoch 2/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6656 - acc: 0.6403Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.6278 - acc: 0.6777
# Epoch 00002: val_loss improved from 0.66794 to 0.62785, saving model to siamese_best.h5
# 16/16 [==============================] - 8s 521ms/step - loss: 0.6655 - acc: 0.6428 - val_loss: 0.6278 - val_acc: 0.6777
# Epoch 3/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6413 - acc: 0.6684Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.5871 - acc: 0.7656
# Epoch 00003: val_loss improved from 0.62785 to 0.58712, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 551ms/step - loss: 0.6397 - acc: 0.6706 - val_loss: 0.5871 - val_acc: 0.7656
# Epoch 4/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6082 - acc: 0.7114Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.5801 - acc: 0.7441
# Epoch 00004: val_loss improved from 0.58712 to 0.58010, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 554ms/step - loss: 0.6117 - acc: 0.7059 - val_loss: 0.5801 - val_acc: 0.7441
# Epoch 5/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.6048 - acc: 0.7210Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.5493 - acc: 0.7598
# Epoch 00005: val_loss improved from 0.58010 to 0.54930, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 555ms/step - loss: 0.6001 - acc: 0.7223 - val_loss: 0.5493 - val_acc: 0.7598
# Epoch 6/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5732 - acc: 0.7443Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.5448 - acc: 0.7598
# Epoch 00006: val_loss improved from 0.54930 to 0.54483, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 550ms/step - loss: 0.5758 - acc: 0.7407 - val_loss: 0.5448 - val_acc: 0.7598
# Epoch 7/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5938 - acc: 0.7342Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.5192 - acc: 0.7793
# Epoch 00007: val_loss improved from 0.54483 to 0.51918, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 555ms/step - loss: 0.5926 - acc: 0.7342 - val_loss: 0.5192 - val_acc: 0.7793
# Epoch 8/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5547 - acc: 0.7629Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.5177 - acc: 0.7832
# Epoch 00008: val_loss improved from 0.51918 to 0.51774, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 560ms/step - loss: 0.5535 - acc: 0.7635 - val_loss: 0.5177 - val_acc: 0.7832
# Epoch 9/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5379 - acc: 0.7676Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.5164 - acc: 0.7637
# Epoch 00009: val_loss improved from 0.51774 to 0.51643, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 568ms/step - loss: 0.5392 - acc: 0.7670 - val_loss: 0.5164 - val_acc: 0.7637
# Epoch 10/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5542 - acc: 0.7496Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4866 - acc: 0.7832
# Epoch 00010: val_loss improved from 0.51643 to 0.48656, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 553ms/step - loss: 0.5516 - acc: 0.7496 - val_loss: 0.4866 - val_acc: 0.7832
# Epoch 11/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5135 - acc: 0.7708Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4833 - acc: 0.7871
# Epoch 00011: val_loss improved from 0.48656 to 0.48334, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 565ms/step - loss: 0.5107 - acc: 0.7720 - val_loss: 0.4833 - val_acc: 0.7871
# Epoch 12/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4999 - acc: 0.7846Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4593 - acc: 0.8086
# Epoch 00012: val_loss improved from 0.48334 to 0.45928, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 568ms/step - loss: 0.4992 - acc: 0.7849 - val_loss: 0.4593 - val_acc: 0.8086
# Epoch 13/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5078 - acc: 0.7825Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4529 - acc: 0.8086
# Epoch 00013: val_loss improved from 0.45928 to 0.45289, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 565ms/step - loss: 0.5089 - acc: 0.7809 - val_loss: 0.4529 - val_acc: 0.8086
# Epoch 14/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4895 - acc: 0.7798Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4925 - acc: 0.7773
# Epoch 00014: val_loss did not improve from 0.45289
# 16/16 [==============================] - 9s 553ms/step - loss: 0.4917 - acc: 0.7789 - val_loss: 0.4925 - val_acc: 0.7773
# Epoch 15/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5131 - acc: 0.7682Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4547 - acc: 0.8086
# Epoch 00015: val_loss did not improve from 0.45289
# 16/16 [==============================] - 9s 562ms/step - loss: 0.5079 - acc: 0.7715 - val_loss: 0.4547 - val_acc: 0.8086
# Epoch 16/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5098 - acc: 0.7777Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4539 - acc: 0.8184
# Epoch 00016: val_loss did not improve from 0.45289
# 16/16 [==============================] - 9s 571ms/step - loss: 0.5072 - acc: 0.7774 - val_loss: 0.4539 - val_acc: 0.8184
# Epoch 17/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4654 - acc: 0.8000Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4882 - acc: 0.7812
# Epoch 00017: val_loss did not improve from 0.45289
# 16/16 [==============================] - 9s 550ms/step - loss: 0.4744 - acc: 0.7933 - val_loss: 0.4882 - val_acc: 0.7812
# Epoch 18/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4672 - acc: 0.8062Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4485 - acc: 0.8242
# Epoch 00018: val_loss improved from 0.45289 to 0.44852, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 569ms/step - loss: 0.4687 - acc: 0.8066 - val_loss: 0.4485 - val_acc: 0.8242
# Epoch 19/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.5400 - acc: 0.7454Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.5650 - acc: 0.6855
# Epoch 00019: val_loss did not improve from 0.44852
# 16/16 [==============================] - 9s 574ms/step - loss: 0.5406 - acc: 0.7462 - val_loss: 0.5650 - val_acc: 0.6855
# Epoch 20/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4649 - acc: 0.7931Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4886 - acc: 0.7832
# Epoch 00020: val_loss did not improve from 0.44852
# 16/16 [==============================] - 9s 565ms/step - loss: 0.4783 - acc: 0.7834 - val_loss: 0.4886 - val_acc: 0.7832
# Epoch 21/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4475 - acc: 0.8175Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4417 - acc: 0.8184
# Epoch 00021: val_loss improved from 0.44852 to 0.44167, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 569ms/step - loss: 0.4471 - acc: 0.8172 - val_loss: 0.4417 - val_acc: 0.8184
# Epoch 22/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4474 - acc: 0.8101Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4247 - acc: 0.8164
# Epoch 00022: val_loss improved from 0.44167 to 0.42473, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 573ms/step - loss: 0.4457 - acc: 0.8112 - val_loss: 0.4247 - val_acc: 0.8164
# Epoch 23/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4549 - acc: 0.8053Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4168 - acc: 0.8125
# Epoch 00023: val_loss improved from 0.42473 to 0.41681, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 579ms/step - loss: 0.4558 - acc: 0.8068 - val_loss: 0.4168 - val_acc: 0.8125
# Epoch 24/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4253 - acc: 0.8180Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4143 - acc: 0.8320
# Epoch 00024: val_loss improved from 0.41681 to 0.41428, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 568ms/step - loss: 0.4267 - acc: 0.8177 - val_loss: 0.4143 - val_acc: 0.8320
# Epoch 25/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4652 - acc: 0.7995Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4094 - acc: 0.8281
# Epoch 00025: val_loss improved from 0.41428 to 0.40935, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 555ms/step - loss: 0.4619 - acc: 0.8008 - val_loss: 0.4094 - val_acc: 0.8281
# Epoch 26/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4421 - acc: 0.8122Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4294 - acc: 0.8066
# Epoch 00026: val_loss did not improve from 0.40935
# 16/16 [==============================] - 9s 560ms/step - loss: 0.4418 - acc: 0.8137 - val_loss: 0.4294 - val_acc: 0.8066
# Epoch 27/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4295 - acc: 0.8286Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.5183 - acc: 0.7812
# Epoch 00027: val_loss did not improve from 0.40935
# 16/16 [==============================] - 9s 550ms/step - loss: 0.4294 - acc: 0.8281 - val_loss: 0.5183 - val_acc: 0.7812
# Epoch 28/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4451 - acc: 0.8154Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4352 - acc: 0.8359
# Epoch 00028: val_loss did not improve from 0.40935
# 16/16 [==============================] - 9s 562ms/step - loss: 0.4424 - acc: 0.8137 - val_loss: 0.4352 - val_acc: 0.8359
# Epoch 29/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4377 - acc: 0.8202Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4246 - acc: 0.8066
# Epoch 00029: val_loss did not improve from 0.40935
# 16/16 [==============================] - 9s 545ms/step - loss: 0.4316 - acc: 0.8236 - val_loss: 0.4246 - val_acc: 0.8066
# Epoch 30/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4273 - acc: 0.8154Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4271 - acc: 0.7969
# Epoch 00030: val_loss did not improve from 0.40935
# 16/16 [==============================] - 9s 553ms/step - loss: 0.4276 - acc: 0.8172 - val_loss: 0.4271 - val_acc: 0.7969
# Epoch 31/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4421 - acc: 0.8032Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4259 - acc: 0.8145
# Epoch 00031: val_loss did not improve from 0.40935
# 16/16 [==============================] - 9s 547ms/step - loss: 0.4428 - acc: 0.8033 - val_loss: 0.4259 - val_acc: 0.8145
# Epoch 32/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4018 - acc: 0.8377Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4142 - acc: 0.8184
# Epoch 00032: val_loss did not improve from 0.40935
# 16/16 [==============================] - 9s 544ms/step - loss: 0.4032 - acc: 0.8371 - val_loss: 0.4142 - val_acc: 0.8184
# Epoch 33/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4362 - acc: 0.8212Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4090 - acc: 0.8301
# Epoch 00033: val_loss improved from 0.40935 to 0.40900, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 559ms/step - loss: 0.4369 - acc: 0.8222 - val_loss: 0.4090 - val_acc: 0.8301
# Epoch 34/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4182 - acc: 0.8156Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4247 - acc: 0.8262
# Epoch 00034: val_loss did not improve from 0.40900
# 16/16 [==============================] - 9s 553ms/step - loss: 0.4167 - acc: 0.8152 - val_loss: 0.4247 - val_acc: 0.8262
# Epoch 35/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4089 - acc: 0.8328Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4184 - acc: 0.8145
# Epoch 00035: val_loss did not improve from 0.40900
# 16/16 [==============================] - 9s 559ms/step - loss: 0.4140 - acc: 0.8311 - val_loss: 0.4184 - val_acc: 0.8145
# Epoch 36/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4152 - acc: 0.8329Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3837 - acc: 0.8359
# Epoch 00036: val_loss improved from 0.40900 to 0.38370, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 558ms/step - loss: 0.4174 - acc: 0.8331 - val_loss: 0.3837 - val_acc: 0.8359
# Epoch 37/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4263 - acc: 0.8186Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4131 - acc: 0.8281
# Epoch 00037: val_loss did not improve from 0.38370
# 16/16 [==============================] - 9s 555ms/step - loss: 0.4291 - acc: 0.8172 - val_loss: 0.4131 - val_acc: 0.8281
# Epoch 38/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4105 - acc: 0.8202Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4157 - acc: 0.8281
# Epoch 00038: val_loss did not improve from 0.38370
# 16/16 [==============================] - 9s 541ms/step - loss: 0.4129 - acc: 0.8197 - val_loss: 0.4157 - val_acc: 0.8281
# Epoch 39/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4314 - acc: 0.8127Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4242 - acc: 0.8105
# Epoch 00039: val_loss did not improve from 0.38370
# 16/16 [==============================] - 9s 550ms/step - loss: 0.4252 - acc: 0.8177 - val_loss: 0.4242 - val_acc: 0.8105
# Epoch 40/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3986 - acc: 0.8313Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4070 - acc: 0.8242
# Epoch 00040: val_loss did not improve from 0.38370
# 16/16 [==============================] - 9s 551ms/step - loss: 0.3955 - acc: 0.8341 - val_loss: 0.4070 - val_acc: 0.8242
# Epoch 41/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4031 - acc: 0.8313Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4421 - acc: 0.7930
# Epoch 00041: val_loss did not improve from 0.38370
# 16/16 [==============================] - 9s 536ms/step - loss: 0.4089 - acc: 0.8316 - val_loss: 0.4421 - val_acc: 0.7930
# Epoch 42/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4066 - acc: 0.8271Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4011 - acc: 0.8477
# Epoch 00042: val_loss did not improve from 0.38370
# 16/16 [==============================] - 9s 549ms/step - loss: 0.4061 - acc: 0.8301 - val_loss: 0.4011 - val_acc: 0.8477
# Epoch 43/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4185 - acc: 0.8233Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4271 - acc: 0.8145
# Epoch 00043: val_loss did not improve from 0.38370
# 16/16 [==============================] - 9s 559ms/step - loss: 0.4180 - acc: 0.8222 - val_loss: 0.4271 - val_acc: 0.8145
# Epoch 44/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4123 - acc: 0.8218Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4016 - acc: 0.8281
# Epoch 00044: val_loss did not improve from 0.38370
# 16/16 [==============================] - 9s 561ms/step - loss: 0.4086 - acc: 0.8241 - val_loss: 0.4016 - val_acc: 0.8281
# Epoch 45/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4009 - acc: 0.8424Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3815 - acc: 0.8516
# Epoch 00045: val_loss improved from 0.38370 to 0.38155, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 564ms/step - loss: 0.4013 - acc: 0.8420 - val_loss: 0.3815 - val_acc: 0.8516
# Epoch 46/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4003 - acc: 0.8398Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3787 - acc: 0.8457
# Epoch 00046: val_loss improved from 0.38155 to 0.37871, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 555ms/step - loss: 0.4069 - acc: 0.8336 - val_loss: 0.3787 - val_acc: 0.8457
# Epoch 47/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3737 - acc: 0.8504Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3872 - acc: 0.8535
# Epoch 00047: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 556ms/step - loss: 0.3749 - acc: 0.8495 - val_loss: 0.3872 - val_acc: 0.8535
# Epoch 48/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3921 - acc: 0.8393Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4018 - acc: 0.8281
# Epoch 00048: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 549ms/step - loss: 0.3887 - acc: 0.8410 - val_loss: 0.4018 - val_acc: 0.8281
# Epoch 49/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3801 - acc: 0.8419Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4041 - acc: 0.8105
# Epoch 00049: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 555ms/step - loss: 0.3806 - acc: 0.8390 - val_loss: 0.4041 - val_acc: 0.8105
# Epoch 50/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4140 - acc: 0.8276Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3892 - acc: 0.8320
# Epoch 00050: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 547ms/step - loss: 0.4096 - acc: 0.8306 - val_loss: 0.3892 - val_acc: 0.8320
# Epoch 51/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4016 - acc: 0.8422Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4055 - acc: 0.8359
# Epoch 00051: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 551ms/step - loss: 0.3974 - acc: 0.8435 - val_loss: 0.4055 - val_acc: 0.8359
# Epoch 52/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.4029 - acc: 0.8333Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3938 - acc: 0.8320
# Epoch 00052: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 578ms/step - loss: 0.4036 - acc: 0.8311 - val_loss: 0.3938 - val_acc: 0.8320
# Epoch 53/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3984 - acc: 0.8403Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4177 - acc: 0.8320
# Epoch 00053: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 570ms/step - loss: 0.4058 - acc: 0.8376 - val_loss: 0.4177 - val_acc: 0.8320
# Epoch 54/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3902 - acc: 0.8334Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4171 - acc: 0.8301
# Epoch 00054: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 558ms/step - loss: 0.3933 - acc: 0.8286 - val_loss: 0.4171 - val_acc: 0.8301
# Epoch 55/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3966 - acc: 0.8387Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4109 - acc: 0.8223
# Epoch 00055: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 555ms/step - loss: 0.3940 - acc: 0.8390 - val_loss: 0.4109 - val_acc: 0.8223
# Epoch 56/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3912 - acc: 0.8403Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4205 - acc: 0.8262
# Epoch 00056: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 565ms/step - loss: 0.3876 - acc: 0.8430 - val_loss: 0.4205 - val_acc: 0.8262
# Epoch 57/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3785 - acc: 0.8483Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4342 - acc: 0.8242
# Epoch 00057: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 563ms/step - loss: 0.3743 - acc: 0.8510 - val_loss: 0.4342 - val_acc: 0.8242
# Epoch 58/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3973 - acc: 0.8345Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4105 - acc: 0.8379
# Epoch 00058: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 563ms/step - loss: 0.3943 - acc: 0.8395 - val_loss: 0.4105 - val_acc: 0.8379
# Epoch 59/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3984 - acc: 0.8308Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3958 - acc: 0.8281
# Epoch 00059: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 571ms/step - loss: 0.3942 - acc: 0.8336 - val_loss: 0.3958 - val_acc: 0.8281
# Epoch 60/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3899 - acc: 0.8377Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4040 - acc: 0.8184
# Epoch 00060: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 558ms/step - loss: 0.3872 - acc: 0.8385 - val_loss: 0.4040 - val_acc: 0.8184
# Epoch 61/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3868 - acc: 0.8393Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4093 - acc: 0.8418
# Epoch 00061: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 565ms/step - loss: 0.3917 - acc: 0.8371 - val_loss: 0.4093 - val_acc: 0.8418
# Epoch 62/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3744 - acc: 0.8366Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3877 - acc: 0.8398
# Epoch 00062: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 562ms/step - loss: 0.3741 - acc: 0.8395 - val_loss: 0.3877 - val_acc: 0.8398
# Epoch 63/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3953 - acc: 0.8271Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4105 - acc: 0.8320
# Epoch 00063: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 566ms/step - loss: 0.3947 - acc: 0.8271 - val_loss: 0.4105 - val_acc: 0.8320
# Epoch 64/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3669 - acc: 0.8589Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4002 - acc: 0.8164
# Epoch 00064: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 566ms/step - loss: 0.3671 - acc: 0.8584 - val_loss: 0.4002 - val_acc: 0.8164
# Epoch 65/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3906 - acc: 0.8377Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4142 - acc: 0.8320
# Epoch 00065: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 560ms/step - loss: 0.3918 - acc: 0.8351 - val_loss: 0.4142 - val_acc: 0.8320
# Epoch 66/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3711 - acc: 0.8435Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4010 - acc: 0.8320
# Epoch 00066: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 559ms/step - loss: 0.3755 - acc: 0.8425 - val_loss: 0.4010 - val_acc: 0.8320
# Epoch 67/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3760 - acc: 0.8488Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4108 - acc: 0.8281
# Epoch 00067: val_loss did not improve from 0.37871
# 16/16 [==============================] - 9s 566ms/step - loss: 0.3840 - acc: 0.8480 - val_loss: 0.4108 - val_acc: 0.8281
# Epoch 68/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3772 - acc: 0.8438Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3667 - acc: 0.8535
# Epoch 00068: val_loss improved from 0.37871 to 0.36671, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 559ms/step - loss: 0.3729 - acc: 0.8470 - val_loss: 0.3667 - val_acc: 0.8535
# Epoch 69/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3686 - acc: 0.8479Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3917 - acc: 0.8379
# Epoch 00069: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 576ms/step - loss: 0.3679 - acc: 0.8477 - val_loss: 0.3917 - val_acc: 0.8379
# Epoch 70/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3710 - acc: 0.8403Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3803 - acc: 0.8301
# Epoch 00070: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 567ms/step - loss: 0.3687 - acc: 0.8395 - val_loss: 0.3803 - val_acc: 0.8301
# Epoch 71/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3836 - acc: 0.8440Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3844 - acc: 0.8359
# Epoch 00071: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 553ms/step - loss: 0.3807 - acc: 0.8450 - val_loss: 0.3844 - val_acc: 0.8359
# Epoch 72/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3768 - acc: 0.8435Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3986 - acc: 0.8379
# Epoch 00072: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 552ms/step - loss: 0.3751 - acc: 0.8425 - val_loss: 0.3986 - val_acc: 0.8379
# Epoch 73/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3668 - acc: 0.8557Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.4006 - acc: 0.8359
# Epoch 00073: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 551ms/step - loss: 0.3673 - acc: 0.8549 - val_loss: 0.4006 - val_acc: 0.8359
# Epoch 74/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3793 - acc: 0.8419Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3948 - acc: 0.8281
# Epoch 00074: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 551ms/step - loss: 0.3856 - acc: 0.8381 - val_loss: 0.3948 - val_acc: 0.8281
# Epoch 75/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3722 - acc: 0.8546Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3819 - acc: 0.8398
# Epoch 00075: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 543ms/step - loss: 0.3769 - acc: 0.8520 - val_loss: 0.3819 - val_acc: 0.8398
# Epoch 76/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3611 - acc: 0.8493Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3792 - acc: 0.8418
# Epoch 00076: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 567ms/step - loss: 0.3557 - acc: 0.8520 - val_loss: 0.3792 - val_acc: 0.8418
# Epoch 77/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3807 - acc: 0.8509Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3908 - acc: 0.8281
# Epoch 00077: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 553ms/step - loss: 0.3827 - acc: 0.8505 - val_loss: 0.3908 - val_acc: 0.8281
# Epoch 78/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3654 - acc: 0.8499Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3820 - acc: 0.8652
# Epoch 00078: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 567ms/step - loss: 0.3646 - acc: 0.8485 - val_loss: 0.3820 - val_acc: 0.8652
# Epoch 79/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3463 - acc: 0.8562Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3917 - acc: 0.8535
# Epoch 00079: val_loss did not improve from 0.36671
# 16/16 [==============================] - 9s 554ms/step - loss: 0.3426 - acc: 0.8594 - val_loss: 0.3917 - val_acc: 0.8535
# Epoch 80/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3656 - acc: 0.8493Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3656 - acc: 0.8516
# Epoch 00080: val_loss improved from 0.36671 to 0.36557, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 554ms/step - loss: 0.3667 - acc: 0.8505 - val_loss: 0.3656 - val_acc: 0.8516
# Epoch 81/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3754 - acc: 0.8403Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3780 - acc: 0.8555
# Epoch 00081: val_loss did not improve from 0.36557
# 16/16 [==============================] - 9s 554ms/step - loss: 0.3780 - acc: 0.8385 - val_loss: 0.3780 - val_acc: 0.8555
# Epoch 82/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3530 - acc: 0.8621Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3682 - acc: 0.8633
# Epoch 00082: val_loss did not improve from 0.36557
# 16/16 [==============================] - 9s 546ms/step - loss: 0.3537 - acc: 0.8604 - val_loss: 0.3682 - val_acc: 0.8633
# Epoch 83/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3663 - acc: 0.8573Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3731 - acc: 0.8457
# Epoch 00083: val_loss did not improve from 0.36557
# 16/16 [==============================] - 9s 565ms/step - loss: 0.3669 - acc: 0.8569 - val_loss: 0.3731 - val_acc: 0.8457
# Epoch 84/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3611 - acc: 0.8525Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3873 - acc: 0.8184
# Epoch 00084: val_loss did not improve from 0.36557
# 16/16 [==============================] - 9s 546ms/step - loss: 0.3637 - acc: 0.8500 - val_loss: 0.3873 - val_acc: 0.8184
# Epoch 85/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3733 - acc: 0.8469Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3630 - acc: 0.8477
# Epoch 00085: val_loss improved from 0.36557 to 0.36297, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 559ms/step - loss: 0.3677 - acc: 0.8505 - val_loss: 0.3630 - val_acc: 0.8477
# Epoch 86/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3513 - acc: 0.8583Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3975 - acc: 0.8301
# Epoch 00086: val_loss did not improve from 0.36297
# 16/16 [==============================] - 9s 572ms/step - loss: 0.3536 - acc: 0.8584 - val_loss: 0.3975 - val_acc: 0.8301
# Epoch 87/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3516 - acc: 0.8562Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3926 - acc: 0.8379
# Epoch 00087: val_loss did not improve from 0.36297
# 16/16 [==============================] - 9s 561ms/step - loss: 0.3496 - acc: 0.8584 - val_loss: 0.3926 - val_acc: 0.8379
# Epoch 88/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3640 - acc: 0.8515Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3756 - acc: 0.8398
# Epoch 00088: val_loss did not improve from 0.36297
# 16/16 [==============================] - 9s 559ms/step - loss: 0.3620 - acc: 0.8525 - val_loss: 0.3756 - val_acc: 0.8398
# Epoch 89/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3496 - acc: 0.8493Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3673 - acc: 0.8418
# Epoch 00089: val_loss did not improve from 0.36297
# 16/16 [==============================] - 9s 550ms/step - loss: 0.3512 - acc: 0.8470 - val_loss: 0.3673 - val_acc: 0.8418
# Epoch 90/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3703 - acc: 0.8546Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3754 - acc: 0.8457
# Epoch 00090: val_loss did not improve from 0.36297
# 16/16 [==============================] - 9s 552ms/step - loss: 0.3708 - acc: 0.8559 - val_loss: 0.3754 - val_acc: 0.8457
# Epoch 91/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3651 - acc: 0.8483Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3679 - acc: 0.8398
# Epoch 00091: val_loss did not improve from 0.36297
# 16/16 [==============================] - 9s 559ms/step - loss: 0.3627 - acc: 0.8505 - val_loss: 0.3679 - val_acc: 0.8398
# Epoch 92/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3342 - acc: 0.8642Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3591 - acc: 0.8594
# Epoch 00092: val_loss improved from 0.36297 to 0.35915, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 559ms/step - loss: 0.3347 - acc: 0.8634 - val_loss: 0.3591 - val_acc: 0.8594
# Epoch 93/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3739 - acc: 0.8515Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3780 - acc: 0.8496
# Epoch 00093: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 564ms/step - loss: 0.3767 - acc: 0.8510 - val_loss: 0.3780 - val_acc: 0.8496
# Epoch 94/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3504 - acc: 0.8594Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3785 - acc: 0.8516
# Epoch 00094: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 547ms/step - loss: 0.3550 - acc: 0.8584 - val_loss: 0.3785 - val_acc: 0.8516
# Epoch 95/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3560 - acc: 0.8536Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4182 - acc: 0.8320
# Epoch 00095: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 553ms/step - loss: 0.3561 - acc: 0.8535 - val_loss: 0.4182 - val_acc: 0.8320
# Epoch 96/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3563 - acc: 0.8584Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3632 - acc: 0.8398
# Epoch 00096: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 558ms/step - loss: 0.3584 - acc: 0.8549 - val_loss: 0.3632 - val_acc: 0.8398
# Epoch 97/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3353 - acc: 0.8647Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3856 - acc: 0.8496
# Epoch 00097: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 572ms/step - loss: 0.3419 - acc: 0.8604 - val_loss: 0.3856 - val_acc: 0.8496
# Epoch 98/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3516 - acc: 0.8562Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4120 - acc: 0.8320
# Epoch 00098: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 553ms/step - loss: 0.3486 - acc: 0.8594 - val_loss: 0.4120 - val_acc: 0.8320
# Epoch 99/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3519 - acc: 0.8642Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3826 - acc: 0.8379
# Epoch 00099: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 543ms/step - loss: 0.3475 - acc: 0.8654 - val_loss: 0.3826 - val_acc: 0.8379
# Epoch 100/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3665 - acc: 0.8483Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3713 - acc: 0.8613
# Epoch 00100: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 547ms/step - loss: 0.3628 - acc: 0.8495 - val_loss: 0.3713 - val_acc: 0.8613
# Epoch 101/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3370 - acc: 0.8642Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3692 - acc: 0.8496
# Epoch 00101: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 562ms/step - loss: 0.3400 - acc: 0.8634 - val_loss: 0.3692 - val_acc: 0.8496
# Epoch 102/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3449 - acc: 0.8609Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3676 - acc: 0.8496
# Epoch 00102: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 554ms/step - loss: 0.3446 - acc: 0.8609 - val_loss: 0.3676 - val_acc: 0.8496
# Epoch 103/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3353 - acc: 0.8641Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3734 - acc: 0.8438
# Epoch 00103: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 569ms/step - loss: 0.3351 - acc: 0.8657 - val_loss: 0.3734 - val_acc: 0.8438
# Epoch 104/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3373 - acc: 0.8711Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3707 - acc: 0.8555
# Epoch 00104: val_loss did not improve from 0.35915
# 16/16 [==============================] - 9s 561ms/step - loss: 0.3420 - acc: 0.8708 - val_loss: 0.3707 - val_acc: 0.8555
# Epoch 105/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3581 - acc: 0.8477Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3564 - acc: 0.8516
# Epoch 00105: val_loss improved from 0.35915 to 0.35642, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 564ms/step - loss: 0.3551 - acc: 0.8505 - val_loss: 0.3564 - val_acc: 0.8516
# Epoch 106/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3335 - acc: 0.8684Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3868 - acc: 0.8359
# Epoch 00106: val_loss did not improve from 0.35642
# 16/16 [==============================] - 9s 559ms/step - loss: 0.3350 - acc: 0.8679 - val_loss: 0.3868 - val_acc: 0.8359
# Epoch 107/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3272 - acc: 0.8610Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3631 - acc: 0.8516
# Epoch 00107: val_loss did not improve from 0.35642
# 16/16 [==============================] - 9s 543ms/step - loss: 0.3252 - acc: 0.8634 - val_loss: 0.3631 - val_acc: 0.8516
# Epoch 108/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3538 - acc: 0.8557Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3493 - acc: 0.8652
# Epoch 00108: val_loss improved from 0.35642 to 0.34934, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 559ms/step - loss: 0.3509 - acc: 0.8574 - val_loss: 0.3493 - val_acc: 0.8652
# Epoch 109/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3419 - acc: 0.8610Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3708 - acc: 0.8477
# Epoch 00109: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 549ms/step - loss: 0.3415 - acc: 0.8619 - val_loss: 0.3708 - val_acc: 0.8477
# Epoch 110/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3402 - acc: 0.8546Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3692 - acc: 0.8555
# Epoch 00110: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 552ms/step - loss: 0.3429 - acc: 0.8535 - val_loss: 0.3692 - val_acc: 0.8555
# Epoch 111/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3380 - acc: 0.8679Epoch 1/500
#  4/16 [======>.......................] - ETA: 9s - loss: 0.3573 - acc: 0.8418
# Epoch 00111: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 559ms/step - loss: 0.3391 - acc: 0.8693 - val_loss: 0.3573 - val_acc: 0.8418
# Epoch 112/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3347 - acc: 0.8684Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3780 - acc: 0.8418
# Epoch 00112: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 539ms/step - loss: 0.3380 - acc: 0.8649 - val_loss: 0.3780 - val_acc: 0.8418
# Epoch 113/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3396 - acc: 0.8658Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3581 - acc: 0.8516
# Epoch 00113: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 549ms/step - loss: 0.3364 - acc: 0.8679 - val_loss: 0.3581 - val_acc: 0.8516
# Epoch 114/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3466 - acc: 0.8589Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3756 - acc: 0.8652
# Epoch 00114: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 543ms/step - loss: 0.3424 - acc: 0.8609 - val_loss: 0.3756 - val_acc: 0.8652
# Epoch 115/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3347 - acc: 0.8684Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3716 - acc: 0.8535
# Epoch 00115: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 553ms/step - loss: 0.3376 - acc: 0.8689 - val_loss: 0.3716 - val_acc: 0.8535
# Epoch 116/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3337 - acc: 0.8658Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3533 - acc: 0.8477
# Epoch 00116: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 541ms/step - loss: 0.3382 - acc: 0.8664 - val_loss: 0.3533 - val_acc: 0.8477
# Epoch 117/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3322 - acc: 0.8663Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3526 - acc: 0.8555
# Epoch 00117: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 539ms/step - loss: 0.3328 - acc: 0.8654 - val_loss: 0.3526 - val_acc: 0.8555
# Epoch 118/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3409 - acc: 0.8668Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3652 - acc: 0.8555
# Epoch 00118: val_loss did not improve from 0.34934
# 16/16 [==============================] - 9s 553ms/step - loss: 0.3468 - acc: 0.8649 - val_loss: 0.3652 - val_acc: 0.8555
# Epoch 119/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3295 - acc: 0.8625Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3384 - acc: 0.8535
# Epoch 00119: val_loss improved from 0.34934 to 0.33835, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 548ms/step - loss: 0.3275 - acc: 0.8624 - val_loss: 0.3384 - val_acc: 0.8535
# Epoch 120/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3235 - acc: 0.8703Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3511 - acc: 0.8594
# Epoch 00120: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 560ms/step - loss: 0.3262 - acc: 0.8687 - val_loss: 0.3511 - val_acc: 0.8594
# Epoch 121/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3296 - acc: 0.8690Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3766 - acc: 0.8594
# Epoch 00121: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 551ms/step - loss: 0.3336 - acc: 0.8669 - val_loss: 0.3766 - val_acc: 0.8594
# Epoch 122/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3364 - acc: 0.8653Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3767 - acc: 0.8457
# Epoch 00122: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 538ms/step - loss: 0.3331 - acc: 0.8659 - val_loss: 0.3767 - val_acc: 0.8457
# Epoch 123/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3321 - acc: 0.8637Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3497 - acc: 0.8555
# Epoch 00123: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 532ms/step - loss: 0.3304 - acc: 0.8669 - val_loss: 0.3497 - val_acc: 0.8555
# Epoch 124/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3289 - acc: 0.8727Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.4015 - acc: 0.8379
# Epoch 00124: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 554ms/step - loss: 0.3271 - acc: 0.8748 - val_loss: 0.4015 - val_acc: 0.8379
# Epoch 125/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3269 - acc: 0.8737Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3659 - acc: 0.8613
# Epoch 00125: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 545ms/step - loss: 0.3244 - acc: 0.8763 - val_loss: 0.3659 - val_acc: 0.8613
# Epoch 126/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3352 - acc: 0.8573Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3514 - acc: 0.8516
# Epoch 00126: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 533ms/step - loss: 0.3277 - acc: 0.8624 - val_loss: 0.3514 - val_acc: 0.8516
# Epoch 127/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3299 - acc: 0.8690Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3576 - acc: 0.8496
# Epoch 00127: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 548ms/step - loss: 0.3314 - acc: 0.8684 - val_loss: 0.3576 - val_acc: 0.8496
# Epoch 128/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3473 - acc: 0.8642Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3460 - acc: 0.8496
# Epoch 00128: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 550ms/step - loss: 0.3504 - acc: 0.8644 - val_loss: 0.3460 - val_acc: 0.8496
# Epoch 129/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3043 - acc: 0.8865Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3571 - acc: 0.8574
# Epoch 00129: val_loss did not improve from 0.33835
# 16/16 [==============================] - 9s 539ms/step - loss: 0.3096 - acc: 0.8833 - val_loss: 0.3571 - val_acc: 0.8574
# Epoch 130/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3225 - acc: 0.8695Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3352 - acc: 0.8555
# Epoch 00130: val_loss improved from 0.33835 to 0.33518, saving model to siamese_best.h5
# 16/16 [==============================] - 9s 537ms/step - loss: 0.3179 - acc: 0.8738 - val_loss: 0.3352 - val_acc: 0.8555
# Epoch 131/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3265 - acc: 0.8801Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3589 - acc: 0.8496
# Epoch 00131: val_loss did not improve from 0.33518
# 16/16 [==============================] - 9s 537ms/step - loss: 0.3272 - acc: 0.8803 - val_loss: 0.3589 - val_acc: 0.8496
# Epoch 132/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3370 - acc: 0.8626Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3512 - acc: 0.8633
# Epoch 00132: val_loss did not improve from 0.33518
# 16/16 [==============================] - 9s 545ms/step - loss: 0.3340 - acc: 0.8634 - val_loss: 0.3512 - val_acc: 0.8633
# Epoch 133/500
# ...
# Epoch 456/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2181 - acc: 0.9172Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3090 - acc: 0.8730
# Epoch 00456: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 544ms/step - loss: 0.2198 - acc: 0.9146 - val_loss: 0.3090 - val_acc: 0.8730
# Epoch 457/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2481 - acc: 0.9093Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2910 - acc: 0.8828
# Epoch 00457: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 542ms/step - loss: 0.2494 - acc: 0.9076 - val_loss: 0.2910 - val_acc: 0.8828
# Epoch 458/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2263 - acc: 0.9156Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2959 - acc: 0.8711
# Epoch 00458: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 538ms/step - loss: 0.2274 - acc: 0.9170 - val_loss: 0.2959 - val_acc: 0.8711
# Epoch 459/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2307 - acc: 0.9073Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2836 - acc: 0.8887
# Epoch 00459: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 543ms/step - loss: 0.2318 - acc: 0.9061 - val_loss: 0.2836 - val_acc: 0.8887
# Epoch 460/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2403 - acc: 0.9042Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2989 - acc: 0.8828
# Epoch 00460: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 543ms/step - loss: 0.2354 - acc: 0.9067 - val_loss: 0.2989 - val_acc: 0.8828
# Epoch 461/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2348 - acc: 0.9130Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3128 - acc: 0.8906
# Epoch 00461: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 537ms/step - loss: 0.2350 - acc: 0.9116 - val_loss: 0.3128 - val_acc: 0.8906
# Epoch 462/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2393 - acc: 0.9024Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2755 - acc: 0.8828
# Epoch 00462: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 550ms/step - loss: 0.2363 - acc: 0.9036 - val_loss: 0.2755 - val_acc: 0.8828
# Epoch 463/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2384 - acc: 0.9056Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3111 - acc: 0.8789
# Epoch 00463: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 542ms/step - loss: 0.2396 - acc: 0.9041 - val_loss: 0.3111 - val_acc: 0.8789
# Epoch 464/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2219 - acc: 0.9066Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2759 - acc: 0.8867
# Epoch 00464: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 541ms/step - loss: 0.2260 - acc: 0.9051 - val_loss: 0.2759 - val_acc: 0.8867
# Epoch 465/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2545 - acc: 0.8981Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3002 - acc: 0.8926
# Epoch 00465: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 540ms/step - loss: 0.2535 - acc: 0.8967 - val_loss: 0.3002 - val_acc: 0.8926
# Epoch 466/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2089 - acc: 0.9167Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2801 - acc: 0.8887
# Epoch 00466: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 549ms/step - loss: 0.2125 - acc: 0.9146 - val_loss: 0.2801 - val_acc: 0.8887
# Epoch 467/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2623 - acc: 0.9019Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2979 - acc: 0.8867
# Epoch 00467: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 542ms/step - loss: 0.2602 - acc: 0.9046 - val_loss: 0.2979 - val_acc: 0.8867
# Epoch 468/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2120 - acc: 0.9188Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3088 - acc: 0.8848
# Epoch 00468: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 554ms/step - loss: 0.2137 - acc: 0.9175 - val_loss: 0.3088 - val_acc: 0.8848
# Epoch 469/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2264 - acc: 0.9093Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2851 - acc: 0.8945
# Epoch 00469: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 536ms/step - loss: 0.2241 - acc: 0.9091 - val_loss: 0.2851 - val_acc: 0.8945
# Epoch 470/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2462 - acc: 0.9072Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2842 - acc: 0.8828
# Epoch 00470: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 545ms/step - loss: 0.2476 - acc: 0.9066 - val_loss: 0.2842 - val_acc: 0.8828
# Epoch 471/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2402 - acc: 0.8992Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2959 - acc: 0.8965
# Epoch 00471: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 542ms/step - loss: 0.2390 - acc: 0.8992 - val_loss: 0.2959 - val_acc: 0.8965
# Epoch 472/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2166 - acc: 0.9119Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2963 - acc: 0.8887
# Epoch 00472: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 544ms/step - loss: 0.2220 - acc: 0.9091 - val_loss: 0.2963 - val_acc: 0.8887
# Epoch 473/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2191 - acc: 0.9135Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3023 - acc: 0.8789
# Epoch 00473: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 551ms/step - loss: 0.2188 - acc: 0.9146 - val_loss: 0.3023 - val_acc: 0.8789
# Epoch 474/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2353 - acc: 0.8971Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2939 - acc: 0.8945
# Epoch 00474: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 540ms/step - loss: 0.2318 - acc: 0.8982 - val_loss: 0.2939 - val_acc: 0.8945
# Epoch 475/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2551 - acc: 0.8992Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2888 - acc: 0.8848
# Epoch 00475: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 545ms/step - loss: 0.2542 - acc: 0.8992 - val_loss: 0.2888 - val_acc: 0.8848
# Epoch 476/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2191 - acc: 0.9141Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3159 - acc: 0.8848
# Epoch 00476: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 538ms/step - loss: 0.2226 - acc: 0.9116 - val_loss: 0.3159 - val_acc: 0.8848
# Epoch 477/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2381 - acc: 0.9094Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2985 - acc: 0.8809
# Epoch 00477: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 553ms/step - loss: 0.2315 - acc: 0.9136 - val_loss: 0.2985 - val_acc: 0.8809
# Epoch 478/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2396 - acc: 0.9082Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3087 - acc: 0.8848
# Epoch 00478: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 539ms/step - loss: 0.2368 - acc: 0.9091 - val_loss: 0.3087 - val_acc: 0.8848
# Epoch 479/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.3453 - acc: 0.8674Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3195 - acc: 0.8809
# Epoch 00479: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 544ms/step - loss: 0.3507 - acc: 0.8664 - val_loss: 0.3195 - val_acc: 0.8809
# Epoch 480/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2834 - acc: 0.8944Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3057 - acc: 0.8848
# Epoch 00480: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 538ms/step - loss: 0.2789 - acc: 0.8947 - val_loss: 0.3057 - val_acc: 0.8848
# Epoch 481/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2478 - acc: 0.8966Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2860 - acc: 0.9023
# Epoch 00481: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 543ms/step - loss: 0.2462 - acc: 0.8972 - val_loss: 0.2860 - val_acc: 0.9023
# Epoch 482/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2445 - acc: 0.8976Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2867 - acc: 0.8848
# Epoch 00482: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 553ms/step - loss: 0.2425 - acc: 0.9006 - val_loss: 0.2867 - val_acc: 0.8848
# Epoch 483/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2311 - acc: 0.9082Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2987 - acc: 0.8809
# Epoch 00483: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 535ms/step - loss: 0.2281 - acc: 0.9091 - val_loss: 0.2987 - val_acc: 0.8809
# Epoch 484/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2222 - acc: 0.9093Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2742 - acc: 0.8945
# Epoch 00484: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 552ms/step - loss: 0.2235 - acc: 0.9066 - val_loss: 0.2742 - val_acc: 0.8945
# Epoch 485/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2206 - acc: 0.9178Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2964 - acc: 0.8828
# Epoch 00485: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 549ms/step - loss: 0.2221 - acc: 0.9165 - val_loss: 0.2964 - val_acc: 0.8828
# Epoch 486/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2181 - acc: 0.9125Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2839 - acc: 0.8887
# Epoch 00486: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 551ms/step - loss: 0.2232 - acc: 0.9111 - val_loss: 0.2839 - val_acc: 0.8887
# Epoch 487/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2349 - acc: 0.9082Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2736 - acc: 0.8906
# Epoch 00487: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 542ms/step - loss: 0.2300 - acc: 0.9096 - val_loss: 0.2736 - val_acc: 0.8906
# Epoch 488/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2558 - acc: 0.8928Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2712 - acc: 0.8945
# Epoch 00488: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 545ms/step - loss: 0.2542 - acc: 0.8957 - val_loss: 0.2712 - val_acc: 0.8945
# Epoch 489/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2437 - acc: 0.9013Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2886 - acc: 0.8926
# Epoch 00489: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 538ms/step - loss: 0.2427 - acc: 0.9031 - val_loss: 0.2886 - val_acc: 0.8926
# Epoch 490/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2387 - acc: 0.9103Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2730 - acc: 0.8887
# Epoch 00490: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 532ms/step - loss: 0.2379 - acc: 0.9096 - val_loss: 0.2730 - val_acc: 0.8887
# Epoch 491/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2316 - acc: 0.9056Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2808 - acc: 0.8867
# Epoch 00491: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 545ms/step - loss: 0.2266 - acc: 0.9076 - val_loss: 0.2808 - val_acc: 0.8867
# Epoch 492/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2261 - acc: 0.9109Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2953 - acc: 0.8809
# Epoch 00492: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 554ms/step - loss: 0.2226 - acc: 0.9131 - val_loss: 0.2953 - val_acc: 0.8809
# Epoch 493/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2392 - acc: 0.9042Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2867 - acc: 0.8730
# Epoch 00493: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 539ms/step - loss: 0.2359 - acc: 0.9041 - val_loss: 0.2867 - val_acc: 0.8730
# Epoch 494/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2317 - acc: 0.9172Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2779 - acc: 0.8945
# Epoch 00494: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 566ms/step - loss: 0.2327 - acc: 0.9141 - val_loss: 0.2779 - val_acc: 0.8945
# Epoch 495/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2217 - acc: 0.9162Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2842 - acc: 0.8965
# Epoch 00495: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 554ms/step - loss: 0.2216 - acc: 0.9155 - val_loss: 0.2842 - val_acc: 0.8965
# Epoch 496/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2242 - acc: 0.9141Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2707 - acc: 0.8906
# Epoch 00496: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 547ms/step - loss: 0.2287 - acc: 0.9141 - val_loss: 0.2707 - val_acc: 0.8906
# Epoch 497/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2353 - acc: 0.9061Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2881 - acc: 0.8887
# Epoch 00497: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 550ms/step - loss: 0.2324 - acc: 0.9071 - val_loss: 0.2881 - val_acc: 0.8887
# Epoch 498/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2167 - acc: 0.9172Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2933 - acc: 0.8867
# Epoch 00498: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 556ms/step - loss: 0.2197 - acc: 0.9146 - val_loss: 0.2933 - val_acc: 0.8867
# Epoch 499/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2323 - acc: 0.9034Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.3024 - acc: 0.8828
# Epoch 00499: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 548ms/step - loss: 0.2284 - acc: 0.9051 - val_loss: 0.3024 - val_acc: 0.8828
# Epoch 500/500
# 15/16 [===========================>..] - ETA: 0s - loss: 0.2303 - acc: 0.9162Epoch 1/500
#  4/16 [======>.......................] - ETA: 8s - loss: 0.2937 - acc: 0.8770
# Epoch 00500: val_loss did not improve from 0.25607
# 16/16 [==============================] - 9s 548ms/step - loss: 0.2285 - acc: 0.9175 - val_loss: 0.2937 - val_acc: 0.8770

# %%
# History of accuracy and loss
tra_loss = history_siamese.history['loss']
tra_acc = history_siamese.history['acc']
val_loss = history_siamese.history['val_loss']
val_acc = history_siamese.history['val_acc']

# Total number of epochs training
epochs = range(1, len(tra_acc)+1)
end_epoch = len(tra_acc)

# Epoch when reached the validation loss minimum
opt_epoch = val_loss.index(min(val_loss)) + 1

# Loss and accuracy on the validation set
end_val_loss = val_loss[-1]
end_val_acc = val_acc[-1]
opt_val_loss = val_loss[opt_epoch-1]
opt_val_acc = val_acc[opt_epoch-1]

# Loss and accuracy on the test set
opt_siamese = models.load_model('siamese_best.h5')
test_loss, test_acc = siamese.evaluate([test_abn_images, test_base_images], test_labels, verbose=False)
opt_test_loss, opt_test_acc = opt_siamese.evaluate([test_abn_images, test_base_images], test_labels, verbose=False)

print("Siamese CNN\n")

print("Epoch [end]: %d" % end_epoch)
print("Epoch [opt]: %d" % opt_epoch)
print("Valid accuracy [end]: %.4f" % end_val_acc)
print("Valid accuracy [opt]: %.4f" % opt_val_acc)
print("Test accuracy [end]:  %.4f" % test_acc)
print("Test accuracy [opt]:  %.4f" % opt_test_acc)
print("Valid loss [end]: %.4f" % end_val_loss)
print("Valid loss [opt]: %.4f" % opt_val_loss)
print("Test loss [end]:  %.4f" % test_loss)
print("Test loss [opt]:  %.4f" % opt_test_loss)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Siamese CNN
#
# Epoch [end]: 500
# Epoch [opt]: 446
# Valid accuracy [end]: 0.8770
# Valid accuracy [opt]: 0.9043
# Test accuracy [end]:  0.8452
# Test accuracy [opt]:  0.8661
# Valid loss [end]: 0.2937
# Valid loss [opt]: 0.2561
# Test loss [end]:  0.3753
# Test loss [opt]:  0.3530

# %%
# Model accuracy
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('Siamese accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.plot(epochs, tra_acc, 'r', label='Training set')
plt.plot(epochs, val_acc, 'g', label='Validation set')
plt.plot(opt_epoch, val_acc[opt_epoch-1], 'go')
plt.vlines(opt_epoch, min(val_acc), opt_val_acc, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_acc, 1, opt_epoch, linestyle="dashed", color='g', linewidth=1)
plt.legend(loc='lower right')

# Model loss
plt.figure(figsize=(7, 7), dpi=80, facecolor='w', edgecolor='k')
plt.title('Siamese loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.plot(epochs, tra_loss, 'r', label='Training set')
plt.plot(epochs, val_loss, 'g', label='Validation set')
plt.plot(opt_epoch, val_loss[opt_epoch-1], 'go')
plt.vlines(opt_epoch, min(val_loss), opt_val_loss, linestyle="dashed", color='g', linewidth=1)
plt.hlines(opt_val_loss, 1, opt_epoch, linestyle="dashed", color='g', linewidth=1)
plt.legend();

# %%
def plot_confusion_matrix(cm, classes, normalize=True, title='Confusion matrix', cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
pred = opt_siamese.predict([test_abn_images, test_base_images])

pred_classes = np.rint(pred)
confusion_mtx = confusion_matrix(test_labels, pred_classes) 
plot_confusion_matrix(confusion_mtx, classes=range(2), normalize=False, title='Siamese CNN confusion matrix')

# %%
def plot_roc(preds, names, titles='ROC curve'):
    plt.figure(figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
    for pred, name in zip(preds, names):
        fpr, tpr, _ = roc_curve(test_labels, pred)
        auc_keras = auc(fpr, tpr)
        plt.plot([0, 1], [0, 1], 'k--')
        plt.plot(fpr, tpr, label=(name +' (area = {:.3f})'.format(auc_keras)))
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.legend(loc='lower right')
    plt.show()

# %%
plot_roc([pred], names=['Siamese CNN'])

# %%
# Classification report

print(classification_report(test_labels, pred_classes, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9241    0.8156    0.8665       179
#            1     0.8146    0.9236    0.8657       157
#
#     accuracy                         0.8661       336
#    macro avg     0.8693    0.8696    0.8661       336
# weighted avg     0.8729    0.8661    0.8661       336
